# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import glob

# %%
LOGS_DIR = './tuning_phase_logs/'
results = [pd.read_csv(path) for path in glob.glob(f"{LOGS_DIR}*csv")]
results = pd.concat(results)
results = results.apply(lambda x: x.apply(lambda y: y.split(' ')[1][:-1]))
results
# Out:
#     eeg_feature        model hidden_channels window_size batch_size  \
# 0         'wav'  'GraphConv'              32         0.5         16
# 1         'wav'  'GraphConv'              32         0.5         16
# 2         'wav'  'GraphConv'              32         0.5         16
# 3         'wav'  'GraphConv'              32         0.5         16
# 4         'wav'  'GraphConv'              32         0.5         16
# ..          ...          ...             ...         ...        ...
# 535       'raw'        'CNN'             128         1.0         16
# 536       'raw'        'CNN'             128         1.0         16
# 537       'raw'        'CNN'             128         1.0         16
# 538       'raw'        'CNN'             128         1.0         16
# 539       'raw'        'CNN'             128         1.0         16
#
#     learning_rate dropout_rate weight_decay activation_funct  \
# 0          0.0005          0.0          0.0           'relu'
# 1          0.0005         0.25          0.0           'relu'
# 2          0.0005          0.5          0.0           'relu'
# 3          0.0005          0.0         0.01           'relu'
# 4          0.0005         0.25         0.01           'relu'
# ..            ...          ...          ...              ...
# 535        0.0005         0.25         0.16           'relu'
# 536        0.0005          0.5         0.16           'relu'
# 537        0.0005          0.0         0.64           'relu'
# 538        0.0005         0.25         0.64           'relu'
# 539        0.0005          0.5         0.64           'relu'
#
#     number_train_samples  ... number_test_samples      mean_test_loss  \
# 0                      1  ...                4699   2.836134570561766
# 1                      1  ...                4699   2.978832143574325
# 2                      1  ...                4699   2.878437662256553
# 3                      1  ...                4699  2.9119609738187755
# 4                      1  ...                4699  2.8862676904870743
# ..                   ...  ...                 ...                 ...
# 535                    8  ...                2292   3.247314208465097
# 536                    8  ...                2292  3.1837246046640484
# 537                    8  ...                2292  3.1840084874921235
# 538                    8  ...                2292   3.227864359321811
# 539                    8  ...                2292   3.209727824722493
#
#                 test_acc              test_f1            test_prec  \
# 0     0.6964380719301979   0.6494297823983672   0.6503318730085728
# 1     0.5478559267929347  0.49870834515878815   0.5049521758422915
# 2     0.6491806767397319   0.5932205631849168   0.6155117716683299
# 3     0.6229915939561609   0.5624178252120107   0.5831159379126979
# 4     0.6389856884443499   0.5751608678390973   0.5854372458237147
# ..                   ...                  ...                  ...
# 535   0.2697016797556719  0.28130362217527816   0.3382702802126931
# 536  0.33367419284467714   0.3193920693516983  0.34162225088445586
# 537  0.33495582460732987   0.3348856015010162  0.38397168775641777
# 538   0.2903441317626527  0.28535176317664307   0.3214417895989602
# 539  0.31423156631762655  0.28847016943779313  0.30623415612508165
#
#                test_reca            test_roc pytorch_total_params  \
# 0     0.6964380719301979    0.94497900062272                36224
# 1     0.5478559267929346  0.8897659457800655                36224
# 2     0.6491806767397318  0.9289735183743559                36224
# 3      0.622991593956161  0.9182955864542116                36224
# 4     0.6389856884443499   0.926554159810292                36224
# ..                   ...                 ...                  ...
# 535   0.2697016797556719  0.6510526367089539                74401
# 536  0.33367419284467714   0.710180440720652                74401
# 537   0.3349558246073298  0.6955369128986498                74401
# 538   0.2903441317626527   0.648529501173292                74401
# 539   0.3142315663176265  0.6896967326662176                74401
#
#              train_time best_epoch
# 0    314.20142698287964        574
# 1    142.31424117088318        249
# 2    140.87648057937622        246
# 3    104.71506094932556        179
# 4    105.73141264915466        176
# ..                  ...        ...
# 535    87.2335569858551        165
# 536   178.8609709739685        373
# 537   66.63139271736145        121
# 538   75.63228726387024        138
# 539  56.788121461868286         97
#
# [8638 rows x 21 columns]

# %% [markdown]
# # Dropout rate = 0.25

# %%
plt.figure(figsize=(16, 12))
# ,'GIN' -> GIN wasnt included in the end
for it, model in enumerate(['MLP','CNN','GraphConv']):
    plt.subplot(4, 1, it+1)
    dr_0 = results[(results['model'] == f'\'{model}\'') & (results['dropout_rate'] == '0.0')]['test_acc'].astype(float).to_numpy()
    dr_025 = results[(results['model'] == f'\'{model}\'') & (results['dropout_rate'] == '0.25')]['test_acc'].astype(float).to_numpy()
    dr_05 = results[(results['model'] == f'\'{model}\'') & (results['dropout_rate'] == '0.5')]['test_acc'].astype(float).to_numpy()
    
    plt.hist(np.round(dr_0,2),bins=100,range=(0,1),align='mid',alpha=0.5,label=f'Dropout 0 = Mean test acc:{dr_0.mean():.3f}')
    plt.hist(np.round(dr_025,2),bins=100,range=(0,1),align='mid',alpha=0.5,label=f'Dropout 0.25 = Mean test acc:{dr_025.mean():.3f}')
    plt.hist(np.round(dr_05,2),bins=100,range=(0,1),align='mid',alpha=0.5,label=f'Dropout 0.5 = Mean test acc:{dr_05.mean():.3f}')
    plt.title(model)
    plt.xlabel("Test accuracy")
    plt.ylabel("Number of configurations")
    plt.legend(loc='upper center')
plt.tight_layout(pad=1.0)
plt.savefig(f'figures/dropout_rate.png')
plt.show()

# %% [markdown]
# # L2 rate = 0

# %%
for model, l2 in [(model,l2) for model in ['MLP','CNN','GraphConv','GIN'] for l2 in [0.0,0.01,0.04,0.16, 0.64] ]:
    res = results[(results['model'] == f'\'{model}\'') & (results['weight_decay'] == str(l2))]['test_acc'].astype(float).to_numpy()
    plt.hist(np.round(res,2),bins=100,range=(0,1),align='mid')
    plt.show()
    print(model,l2)
    print(res.mean())
# Out:
# MLP 0.0
# 0.6173310347373873
# MLP 0.01
# 0.6176974750957612
# MLP 0.04
# 0.6180371132711108
# MLP 0.16
# 0.6157544244667603
# MLP 0.64
# 0.6199440326050417
# CNN 0.0
# 0.5856942625714883
# CNN 0.01
# 0.5831214538464243
# CNN 0.04
# 0.5834965127858449
# CNN 0.16
# 0.5940450489370809
# CNN 0.64
# 0.5846358406991035
# GraphConv 0.0
# 0.6297267754637809
# GraphConv 0.01
# 0.6346491822605026
# GraphConv 0.04
# 0.631222578475512
# GraphConv 0.16
# 0.6287701766171091
# GraphConv 0.64
# 0.6313798820284778
# GIN 0.0
# 0.6326182009574534
# GIN 0.01
# 0.6319032150004888
# GIN 0.04
# 0.6280426985249322
# GIN 0.16
# 0.6310219254203628
# GIN 0.64
# 0.6294759724992866
